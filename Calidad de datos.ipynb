# %% [markdown]
# # Calidad de datos

# %% [markdown]
# ## SET UP

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sqlalchemy as sa

# %% [markdown]
# ## Importar datos

# %%
# Creación de conexión a base de datos SQLite
con = sa.create_engine('sqlite:///Datos/airbnb.db')

# %% [markdown]
# Para un caso donde no tuvieramos la documentación de la base de datos, podríamos consultar las tablas que contiene a través de la siguiente manera:

# %%
# Inspección de tablas en la base de datos
from sqlalchemy import inspect
insp = inspect(con)
tablas = insp.get_table_names()
tablas
# Out:
# ['listings', 'listings_det']

# %%
# Carga de datos desde la base de datos
listings = pd.read_sql('listings', con)
listings_det = pd.read_sql('listings_det', con)

# %%
listings.head()
# Out:
#    index     id                                      name    host_id  \
# 0      0   6369  Rooftop terrace room ,  ensuite bathroom      13660
# 1      1  21853                      Bright and airy room      83531
# 2      2  23001         Apartmento Arganzuela- Madrid Rio      82175
# 3      3  24805                    Gran Via Studio Madrid  346366726
# 4      4  26825        Single Room whith private Bathroom     114340
#
#   host_name neighbourhood_group   neighbourhood  latitude  longitude  \
# 0     Simon           Chamartín  Hispanoamérica  40.45724   -3.67688
# 1     Abdel              Latina        Cármenes  40.40381   -3.74130
# 2     Jesus          Arganzuela         Legazpi  40.38840   -3.69511
# 3         A              Centro     Universidad  40.42183   -3.70529
# 4  Agustina          Arganzuela         Legazpi  40.38975   -3.69018
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room     60               1                 80  2019-05-14
# 1     Private room     31               4                 33  2018-05-29
# 2  Entire home/apt     50              15                  0        None
# 3  Entire home/apt     92               5                 12  2020-03-01
# 4     Private room     26               2                149  2018-05-15
#
#    reviews_per_month  calculated_host_listings_count  availability_365  \
# 0               1.21                               2               180
# 1               0.39                               2               364
# 2                NaN                               5               222
# 3               0.51                               1               115
# 4               1.65                               1               349
#
#    number_of_reviews_ltm license
# 0                      4    None
# 1                      0    None
# 2                      0    None
# 3                      2    None
# 4                      0    None

# %%
listings_det.head()
# Out:
#    index     id                         listing_url       scrape_id  \
# 0      0   6369   https://www.airbnb.com/rooms/6369  20210910193531
# 1      1  21853  https://www.airbnb.com/rooms/21853  20210910193531
# 2      2  23001  https://www.airbnb.com/rooms/23001  20210910193531
# 3      3  24805  https://www.airbnb.com/rooms/24805  20210910193531
# 4      4  26825  https://www.airbnb.com/rooms/26825  20210910193531
#
#   last_scraped                                      name  \
# 0   2021-09-11  Rooftop terrace room ,  ensuite bathroom
# 1   2021-09-11                      Bright and airy room
# 2   2021-09-11         Apartmento Arganzuela- Madrid Rio
# 3   2021-09-11                    Gran Via Studio Madrid
# 4   2021-09-11        Single Room whith private Bathroom
#
#                                          description  \
# 0  Excellent connection with the AIRPORT and EXHI...
# 1  We have a quiet and sunny room with a good vie...
# 2  Apartamento de tres dormitorios dobles, gran s...
# 3  Studio located 50 meters from Gran Via, next t...
# 4  Nice and cozy roon for one person with a priva...
#
#                                neighborhood_overview  \
# 0                                               None
# 1  We live in a leafy neighbourhood with plenty o...
# 2  Barrio Arganzuela, junto a Madrid Rio, zonas c...
# 3  The area is next to the Gran Via, so people li...
# 4  Es un barrio muy tranquilo, en una zona de Mad...
#
#                                          picture_url    host_id  ...  \
# 0  https://a0.muscache.com/pictures/683224/4cc318...      13660  ...
# 1  https://a0.muscache.com/pictures/68483181/87bc...      83531  ...
# 2  https://a0.muscache.com/pictures/58e6a770-509c...      82175  ...
# 3  https://a0.muscache.com/pictures/miso/Hosting-...  346366726  ...
# 4  https://a0.muscache.com/pictures/149358/218d5b...     114340  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                        4.89                   4.77                4.85
# 1                        4.82                   4.21                4.67
# 2                         NaN                    NaN                 NaN
# 3                        5.00                   5.00                4.83
# 4                        4.71                   4.70                4.72
#
#   license instant_bookable calculated_host_listings_count  \
# 0    None                f                              2
# 1    None                f                              2
# 2    None                f                              5
# 3    None                f                              1
# 4    None                f                              1
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           0
# 1                                           0
# 2                                           4
# 3                                           1
# 4                                           0
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            2
# 1                                            2
# 2                                            1
# 3                                            0
# 4                                            1
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0              1.21
# 1                                           0              0.39
# 2                                           0               NaN
# 3                                           0              0.51
# 4                                           0              1.65
#
# [5 rows x 75 columns]
